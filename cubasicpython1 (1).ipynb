# %% [markdown]
# # Number

# %% [markdown]
# In : Input; Out : Output

# %%
#operation
1+2
# Out:
# 30

# %%
5+5*5
# Out:
# 30

# %%
#integer
type(9)
# Out:
# int

# %%
#float
type(8.33)
# Out:
# float

# %% [markdown]
# # String

# %%
'text here'
# Out:
# 'text here'

# %%
str(1.0e5)
# Out:
# '100000.0'

# %%
#extract
text='texthereforyou'
text[0]
# Out:
# 't'

# %%
text[1]
# Out:
# 'e'

# %%
text[0:10]
# Out:
# 'textherefo'

# %% [markdown]
# # Variables

# %%
a=75
b=54

# %%
a+b
# Out:
# 129
